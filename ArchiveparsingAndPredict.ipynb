# %%
import requests
res=requests.get('https://www.nseindia.com/products/dynaContent/equities/equities/histscrip.jsp?symbolCode=309&symbol=FEDERALBNK&symbol=federal&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate=01-01-2018&toDate=01-12-2018&dataType=PRICEVOLUMEDELIVERABLE')
print(str(res.text))
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="historic-bar" style="width:950px; margin-bottom:5px;"><span><nobr>Data for FEDERALBNK - EQ from Jan 01, 2018 to Dec 01, 2018</nobr></span> <span class="download-data-link"><a download target"_blank" style='cursor:pointer' >Download file in csv format</a></span></div>
#
# 	  <table border="0" cellpadding="4" cellspacing="1" bgcolor="#969696" width="950">
#       <tr style="height:20">
# 	  <th nowrap>Symbol</th>
# 	  <th nowrap>Series</th>
# 	  <th nowrap>Date</td>
# 	  <th nowrap>Prev Close</th>
# 	  <th nowrap>Open Price</th>
# 	  <th nowrap>High Price</th>
# 	  <th nowrap>Low Price</th>
# 	  <th nowrap>Last Price</th>
# 	  <th nowrap>Close Price</th>
# 	  <th nowrap>VWAP</th>
# 	  <th nowrap>Total Traded<br /> Quantity</th>
# 	  <th nowrap>Turnover<br /><img src="/images/rup_t1.gif" alt="Rs." border="0"/> </th>
# 	  <th nowrap>No. of <br />Trades</th>
# 	  <th nowrap>Deliverable<br />Qty</th>
# ...

# %%
import xml.etree.ElementTree as ET
import csv

import re
line = res.content.decode('utf-8')
line = re.sub(r"\\+", "", line)
result = line.index('<input>')
line = line[:-result]
# res.content.replace()
# print(line)
# parser = ET.XMLParser(recover=True)
# print(line)

print(line)
parser = ET.XMLParser(encoding="utf-8")
tree = ET.fromstring(line, parser=parser)


root = tree.getroot()

# open a file for writing

Resident_data = open('C:\\Users\\nitishsh\\githuib\\backup\\newFile.csv', 'w+')

# create the csv writer object

csvwriter = csv.writer(Resident_data)
resident_head = []

count = 0
for member in root.findall('Resident'):
	resident = []
	address_list = []
	if count == 0:
		symbol = member.find('Symbol').tag
		resident_head.append(symbol)
		series = member.find('Series').tag
		resident_head.append(series)
		date = member.find('Date').tag
		resident_head.append(date)
		Address = member[3].tag
# 		resident_head.append(Address)
# 		Address = member[4].tag
# 		resident_head.append(Address)
# 		Address = member[5].tag
# 		resident_head.append(Address)
# 		Address = member[6].tag
# 		resident_head.append(Address)
# 		Address = member[7].tag
# 		resident_head.append(Address)
# 		Address = member[8].tag
# 		resident_head.append(Address)
# 		Address = member[9].tag
# 		resident_head.append(Address)
# 		Address = member[10].tag
# 		resident_head.append(Address)
# 		Address = member[11].tag
# 		resident_head.append(Address)
# 		Address = member[12].tag
# 		resident_head.append(Address)
# 		Address = member[13].tag
# 		resident_head.append(Address)
# 		Address = member[14].tag
# 		resident_head.append(Address)

# Prev Close	Open Price	High Price	Low Price	Last Price	Close Price	VWAP	Total Traded Quantity	Turnover Rs.	No. of 
# Trades	Deliverable Qty	% Dly Qt to Traded Qty

		print(resident_head)
		csvwriter.writerow(resident_head)
		count = count + 1

	symbol = member.find('Symbol').text
	resident.append(name)
	series = member.find('Series').text
	resident.append(series)
	date = member.find('Date').text
	resident.append(date)
# 	Address = member[3][0].text
# 	address_list.append(Address)
# 	City = member[3][1].text
# 	address_list.append(City)
# 	StateCode = member[3][2].text
# 	address_list.append(StateCode)
# 	PostalCode = member[3][3].text
# 	address_list.append(PostalCode)
# 	resident.append(address_list)
	csvwriter.writerow(resident)
Resident_data.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-cc3e6312c512> in <module>()
#       5 line = res.content.decode('utf-8')
#       6 line = re.sub(r"\\+", "", line)
# ----> 7 result = line.index('<input>')
#       8 line = line[:-result]
#       9 # res.content.replace()
#
# ValueError: substring not found
